# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhoshi2003/CodSoft_Internship/blob/main/Car_sales_predction(ANN%2C_Codesoft).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 19ms/step - loss: 0.0533 - mean_absolute_error: 0.1921 - val_loss: 0.0361 - val_mean_absolute_error: 0.1508
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0236 - mean_absolute_error: 0.1225 - val_loss: 0.0213 - val_mean_absolute_error: 0.1155
# Epoch 3/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.1122 - val_loss: 0.0207 - val_mean_absolute_error: 0.1177
# Epoch 4/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0200 - mean_absolute_error: 0.1118 - val_loss: 0.0192 - val_mean_absolute_error: 0.1122
# Epoch 5/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0180 - mean_absolute_error: 0.1061 - val_loss: 0.0180 - val_mean_absolute_error: 0.1080
# Epoch 6/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0170 - mean_absolute_error: 0.1029 - val_loss: 0.0173 - val_mean_absolute_error: 0.1053
# Epoch 7/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.1001 - val_loss: 0.0160 - val_mean_absolute_error: 0.1024
# Epoch 8/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0150 - mean_absolute_error: 0.0965 - val_loss: 0.0150 - val_mean_absolute_error: 0.0997
# Epoch 9/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0932 - val_loss: 0.0140 - val_mean_absolute_error: 0.0960
# Epoch 10/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0896 - val_loss: 0.0130 - val_mean_absolute_error: 0.0917
# Epoch 11/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0117 - mean_absolute_error: 0.0847 - val_loss: 0.0118 - val_mean_absolute_error: 0.0886
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0104 - mean_absolute_error: 0.0800 - val_loss: 0.0108 - val_mean_absolute_error: 0.0852
# Epoch 13/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - mean_absolute_error: 0.0763 - val_loss: 0.0098 - val_mean_absolute_error: 0.0810
# Epoch 14/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - mean_absolute_error: 0.0718 - val_loss: 0.0089 - val_mean_absolute_error: 0.0767
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - mean_absolute_error: 0.0681 - val_loss: 0.0081 - val_mean_absolute_error: 0.0726
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - mean_absolute_error: 0.0646 - val_loss: 0.0072 - val_mean_absolute_error: 0.0683
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0609 - val_loss: 0.0066 - val_mean_absolute_error: 0.0651
# Epoch 18/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0055 - mean_absolute_error: 0.0575 - val_loss: 0.0059 - val_mean_absolute_error: 0.0618
# Epoch 19/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0050 - mean_absolute_error: 0.0543 - val_loss: 0.0054 - val_mean_absolute_error: 0.0586
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0526 - val_loss: 0.0047 - val_mean_absolute_error: 0.0552
# Epoch 21/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0040 - mean_absolute_error: 0.0490 - val_loss: 0.0045 - val_mean_absolute_error: 0.0535
# Epoch 22/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0035 - mean_absolute_error: 0.0460 - val_loss: 0.0036 - val_mean_absolute_error: 0.0490
# Epoch 23/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0383 - val_loss: 0.0026 - val_mean_absolute_error: 0.0407
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0300 - val_loss: 0.0016 - val_mean_absolute_error: 0.0327
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 26/50
# 10/10 [==============================] - 0s 4ms/step - loss: 8.1628e-04 - mean_absolute_error: 0.0219 - val_loss: 9.1996e-04 - val_mean_absolute_error: 0.0241
# Epoch 27/50
# 10/10 [==============================] - 0s 4ms/step - loss: 6.1434e-04 - mean_absolute_error: 0.0189 - val_loss: 7.0966e-04 - val_mean_absolute_error: 0.0208
# Epoch 28/50
# 10/10 [==============================] - 0s 4ms/step - loss: 4.7554e-04 - mean_absolute_error: 0.0165 - val_loss: 5.6699e-04 - val_mean_absolute_error: 0.0181
# Epoch 29/50
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9185e-04 - mean_absolute_error: 0.0148 - val_loss: 4.4386e-04 - val_mean_absolute_error: 0.0161
# Epoch 30/50
# 10/10 [==============================] - 0s 6ms/step - loss: 3.2229e-04 - mean_absolute_error: 0.0135 - val_loss: 4.0124e-04 - val_mean_absolute_error: 0.0140
# Epoch 31/50
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4363e-04 - mean_absolute_error: 0.0116 - val_loss: 3.5695e-04 - val_mean_absolute_error: 0.0126
# Epoch 32/50
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9819e-04 - mean_absolute_error: 0.0103 - val_loss: 3.2315e-04 - val_mean_absolute_error: 0.0114
# Epoch 33/50
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6572e-04 - mean_absolute_error: 0.0092 - val_loss: 3.2288e-04 - val_mean_absolute_error: 0.0106
# Epoch 34/50
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4579e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7171e-04 - val_mean_absolute_error: 0.0095
# Epoch 35/50
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2037e-04 - mean_absolute_error: 0.0076 - val_loss: 2.5439e-04 - val_mean_absolute_error: 0.0092
# Epoch 36/50
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0698e-04 - mean_absolute_error: 0.0071 - val_loss: 2.5671e-04 - val_mean_absolute_error: 0.0082
# Epoch 37/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.5920e-05 - mean_absolute_error: 0.0067 - val_loss: 2.5455e-04 - val_mean_absolute_error: 0.0078
# Epoch 38/50
# 10/10 [==============================] - 0s 3ms/step - loss: 8.7652e-05 - mean_absolute_error: 0.0064 - val_loss: 2.3858e-04 - val_mean_absolute_error: 0.0073
# Epoch 39/50
# 10/10 [==============================] - 0s 5ms/step - loss: 8.1972e-05 - mean_absolute_error: 0.0061 - val_loss: 2.1967e-04 - val_mean_absolute_error: 0.0076
# Epoch 40/50
# 10/10 [==============================] - 0s 5ms/step - loss: 7.3073e-05 - mean_absolute_error: 0.0054 - val_loss: 2.1263e-04 - val_mean_absolute_error: 0.0074
# Epoch 41/50
# 10/10 [==============================] - 0s 3ms/step - loss: 6.8518e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0968e-04 - val_mean_absolute_error: 0.0076
# Epoch 42/50
# 10/10 [==============================] - 0s 7ms/step - loss: 6.7445e-05 - mean_absolute_error: 0.0054 - val_loss: 2.1811e-04 - val_mean_absolute_error: 0.0062
# Epoch 43/50
# 10/10 [==============================] - 0s 4ms/step - loss: 6.1509e-05 - mean_absolute_error: 0.0052 - val_loss: 2.1209e-04 - val_mean_absolute_error: 0.0060
# Epoch 44/50
# 10/10 [==============================] - 0s 5ms/step - loss: 5.7947e-05 - mean_absolute_error: 0.0048 - val_loss: 2.0262e-04 - val_mean_absolute_error: 0.0058
# Epoch 45/50
# 10/10 [==============================] - 0s 3ms/step - loss: 5.2750e-05 - mean_absolute_error: 0.0045 - val_loss: 1.8919e-04 - val_mean_absolute_error: 0.0059
# Epoch 46/50
# 10/10 [==============================] - 0s 3ms/step - loss: 4.9747e-05 - mean_absolute_error: 0.0043 - val_loss: 1.8274e-04 - val_mean_absolute_error: 0.0064
# Epoch 47/50
# 10/10 [==============================] - 0s 5ms/step - loss: 4.8232e-05 - mean_absolute_error: 0.0043 - val_loss: 1.8343e-04 - val_mean_absolute_error: 0.0055
# Epoch 48/50
# 10/10 [==============================] - 0s 3ms/step - loss: 4.4746e-05 - mean_absolute_error: 0.0040 - val_loss: 1.7190e-04 - val_mean_absolute_error: 0.0060
# Epoch 49/50
# 10/10 [==============================] - 0s 3ms/step - loss: 4.3837e-05 - mean_absolute_error: 0.0040 - val_loss: 1.6919e-04 - val_mean_absolute_error: 0.0059
# Epoch 50/50
# 10/10 [==============================] - 0s 3ms/step - loss: 4.1467e-05 - mean_absolute_error: 0.0042 - val_loss: 1.8530e-04 - val_mean_absolute_error: 0.0057

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.996884477829487
